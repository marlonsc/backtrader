# %% [markdown]
# ### Backtrader多数据画图

# %%
from qmtbt import QMTStore
from datetime import datetime
import backtrader as bt
import pandas as pd
import efinance
import matplotlib.pyplot as plt

plt.style.use("default")


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class SmaCross(bt.SignalStrategy):
    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=10), bt.ind.SMA(period=30)
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)


class MultiSMACrossStrategy(bt.Strategy):
    params = (("fast_length", 5), ("slow_length", 25))

    def __init__(self):
        self.crossovers = []

        for d in self.datas:
            ma_fast = bt.ind.SMA(d, period=self.params.fast_length)
            ma_slow = bt.ind.SMA(d, period=self.params.slow_length)

            self.crossovers.append(bt.ind.CrossOver(ma_fast, ma_slow))

    def next(self):
        for i, d in enumerate(self.datas):
            if not self.getposition(d).size:
                if self.crossovers[i] > 0:
                    self.buy(data=d, size=100)
            elif self.crossovers[i] < 0:
                if self.getposition(d).size > 0:
                    self.close(data=d)


class PrintData(bt.Strategy):
    def next(self):
        for data in self.datas:
            print(f"Data for {data._name}:")
            print(f"Date: {data.datetime.date(0)}")
            print(
                f"Open: {data.open[0]}, High: {data.high[0]}, Low: {data.low[0]},"
                f" Close: {data.close[0]}, Volume: {data.volume[0]}"
            )
            print("-" * 40)


if __name__ == "__main__":

    # 获取数据
    start_time = datetime(2020, 1, 1)
    end_time = datetime(2021, 1, 1)
    cerebro = bt.Cerebro()

    # dataframe = get_k_data('000001', begin=start_time, end=end_time)
    # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
    store = QMTStore()
    code_list = ["000001.SZ", "600519.SH", "000002.SZ"]
    datas = store.getdatas(
        code_list=code_list,
        timeframe=bt.TimeFrame.Days,
        fromdate=datetime(2020, 1, 1),
        todate=datetime(2021, 1, 1),
        live=False,
    )

    for data in datas:
        cerebro.adddata(data)
    cerebro.addstrategy(MultiSMACrossStrategy)
    start_cash = 1000000
    cerebro.broker.setcash(start_cash)
    cerebro.broker.setcommission(commission=0.00025)
    cerebro.run()
    # cerebro.plot(iplot=False)

    # print(cerebro.runstrats[0])
    print(cerebro.broker.getvalue())
# Out:
# 下载数据000001.SZ
# 000001.SZ历史数据装载成功！
# 下载数据600519.SH
# 600519.SH历史数据装载成功！
# 下载数据000002.SZ
# 000002.SZ历史数据装载成功！
# 1059701.0686667003

# %% [markdown]
# ### 多线程

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import efinance
import matplotlib.pyplot as plt

plt.style.use("default")


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class SmaCross(bt.SignalStrategy):
    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=10), bt.ind.SMA(period=30)
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)


class MultiSMACrossStrategy(bt.Strategy):
    params = (("fast_length", 5), ("slow_length", 25))

    def __init__(self):
        self.crossovers = []

        for d in self.datas:
            ma_fast = bt.ind.SMA(d, period=self.params.fast_length)
            ma_slow = bt.ind.SMA(d, period=self.params.slow_length)

            self.crossovers.append(bt.ind.CrossOver(ma_fast, ma_slow))

    def next(self):
        for i, d in enumerate(self.datas):
            if not self.getposition(d).size:
                if self.crossovers[i] > 0:
                    self.buy(data=d, size=100)
            elif self.crossovers[i] < 0:
                if self.getposition(d).size > 0:
                    self.close(data=d)


if __name__ == "__main__":
    store = QMTStore()
    # 获取数据
    start_time = datetime(2020, 1, 1)
    end_time = datetime(2021, 1, 1)
    cerebro = bt.Cerebro(maxcpus=10)
    # dataframe = get_k_data('000001', begin=start_time, end=end_time)
    # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
    # cerebro.adddata(data)
    # dataframe = get_k_data('600519', begin=start_time, end=end_time)
    # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
    # cerebro.adddata(data)
    # dataframe = get_k_data('000002', begin=start_time, end=end_time)
    # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
    code_list = ["000001.SH", "600519.SH", "000002.SH"]
    datas = store.getdatas(
        code_list=code_list,
        timeframe=bt.TimeFrame.Days,
        fromdate=datetime(2020, 1, 1),
        todate=datetime(2021, 1, 1),
        live=False,
    )
    store.setdatas(cerebro, datas)
    # cerebro.adddata(data)
    cerebro.addstrategy(MultiSMACrossStrategy)
    start_cash = 1000000
    cerebro.broker.setcash(start_cash)
    cerebro.broker.setcommission(commission=0.00025)
    cerebro.run()
    cerebro.plot(iplot=False)

    print(cerebro.runstrats[0])
    print(cerebro.broker.getvalue())

# %% [markdown]
# ### Sko优化demo

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import efinance
import optuna


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class SmaCross(bt.SignalStrategy):
    params = (
        ("period1", 10),
        ("period2", 30),
    )

    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=self.p.period1), bt.ind.SMA(
            period=self.p.period2
        )
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)


start_time = datetime(2020, 1, 1)
end_time = datetime(2021, 1, 1)
# dataframe = get_k_data('600519', begin=start_time, end=end_time)
# # =============== 为系统注入数据 =================
# # 加载数据
# data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)

store = QMTStore()
code_list = ["600519.SH"]
data = store.getdata(
    dataname="600519.SH",
    timeframe=bt.TimeFrame.Days,
    fromdate=datetime(2020, 1, 1),
    todate=datetime(2021, 1, 1),
    live=False,
)


def backtest(p) -> float:
    p1, p2 = p
    strategy = SmaCross
    cerebro = bt.Cerebro()
    cerebro.adddata(data)
    cerebro.addstrategy(strategy, period1=int(p1), period2=int(p2))
    start_cash = 1000000
    cerebro.broker.setcash(start_cash)
    cerebro.broker.setcommission(commission=0.00025)
    cerebro.run()
    print(-(start_cash - cerebro.broker.getvalue()))
    return -(start_cash - cerebro.broker.getvalue())


from sko.GA import GA

ga = GA(
    func=backtest,
    n_dim=2,
    size_pop=10,
    max_iter=100,
    prob_mut=0.001,
    lb=[1, 1],
    ub=[50, 50],
    precision=1e-7,
)
best_x, best_y = ga.run()
print("best_x:", best_x, "\n", "best_y:", best_y)

# from sko.DE import DE
# de = DE(func=backtest, n_dim=2, size_pop=10, max_iter=100, lb=[1, 1], ub=[50, 50])
# best_x, best_y = de.run()
# print('best_x:', best_x, '\n', 'best_y:', best_y)

# from sko.PSO import PSO
# pso = PSO(func=backtest, n_dim=2, pop=10, max_iter=100, lb=[1, 1], ub=[50, 50], w=0.8, c1=0.5, c2=0.5)
# pso.run()
# print('best_x is ', pso.gbest_x, 'best_y is', pso.gbest_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 41
#      35 end_time = datetime(2021, 1, 1)
#      36 # dataframe = get_k_data('600519', begin=start_time, end=end_time)
#      37 # # =============== 为系统注入数据 =================
#      38 # # 加载数据
#      39 # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
# ---> 41 store = QMTStore()
#      42 code_list=['600519.SH']
#      43 data = store.getdata(dataname='600519.SH', timeframe=bt.TimeFrame.Days, fromdate=datetime(2020, 1, 1),
#      44 todate=datetime(2021, 1, 1),live=False)
#
# NameError: name 'QMTStore' is not defined

# %% [markdown]
# ### Optuna优化接口

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import efinance
import optuna


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class SmaCross(bt.SignalStrategy):
    params = (
        ("period1", 10),
        ("period2", 30),
    )

    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=self.p.period1), bt.ind.SMA(
            period=self.p.period2
        )
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)


# start_time = datetime(2020, 1, 1)
# end_time = datetime(2021, 1, 1)
# dataframe = get_k_data('600519', begin=start_time, end=end_time)
# data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
store = QMTStore()
code_list = ["600519.SH"]
data = store.getdata(
    dataname="600519.SH",
    timeframe=bt.TimeFrame.Days,
    fromdate=datetime(2020, 1, 1),
    todate=datetime(2021, 1, 1),
    live=False,
)


def backtest(trial) -> float:
    p1 = trial.suggest_int("p1", 1, 50)
    p2 = trial.suggest_int("p2", 1, 50)
    strategy = SmaCross
    cerebro = bt.Cerebro()
    cerebro.adddata(data)
    cerebro.addstrategy(strategy, period1=int(p1), period2=int(p2))
    start_cash = 1000000
    cerebro.broker.setcash(start_cash)
    cerebro.broker.setcommission(commission=0.00025)
    cerebro.run()
    return start_cash - cerebro.broker.getvalue()


study = optuna.create_study(direction="maximize")
study.optimize(backtest, n_trials=100, n_jobs=1)
trial = study.best_trial

print("\tBest Score: {}".format(trial.value))
print("\tBest Params: {}".format(trial.params))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 38
#      31         self.signal_add(bt.SIGNAL_LONG, crossover)
#      34 # start_time = datetime(2020, 1, 1)
#      35 # end_time = datetime(2021, 1, 1)
#      36 # dataframe = get_k_data('600519', begin=start_time, end=end_time)
#      37 # data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
# ---> 38 store = QMTStore()
#      39 code_list=['600519.SH']
#      40 data = store.getdata(dataname='600519.SH', timeframe=bt.TimeFrame.Days, fromdate=datetime(2020, 1, 1),
#      41 todate=datetime(2021, 1, 1),live=False)
#
# NameError: name 'QMTStore' is not defined

# %% [markdown]
# ### Backtrader带log记录版本

# %%
import backtrader
from loguru import logger
import pandas as pd
import efinance
from datetime import datetime, timedelta


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """
    根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    :return:
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class MyStrategy1(backtrader.Strategy):  # 策略
    def __init__(self):
        # 初始化交易指令、买卖价格和手续费
        self.close_price = self.datas[0].close  # 这里加一个数据引用，方便后续操作
        self.sma = backtrader.indicators.SimpleMovingAverage(
            self.datas[0], period=5
        )  # 借用这个策略，计算5日的均线
        self.order_list = []

    def notify_order(self, order):  # 固定写法，查看订单情况
        # 查看订单情况
        if order.status in [order.Submitted, order.Accepted]:  # 接受订单交易，正常情况
            return
        if order.status in [order.Completed]:
            if order.isbuy():
                logger.debug(
                    "{} 已买入, 购入金额 {} 手续费 {}",
                    order.ref,
                    order.executed.value,
                    order.executed.comm,
                )
            elif order.issell():
                logger.debug(
                    "{} 已卖出, 卖出金额 {} 手续费 {}",
                    order.ref,
                    order.executed.value,
                    order.executed.comm,
                )
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            logger.debug("{} 订单取消、保证金不足、金额不足拒绝交易", order.ref)
        elif order.status in [order.Expired]:
            logger.debug("订单 {} 超过时效，已取消", order.ref)

    def next(
        self,
    ):  # 固定的函数，框架执行过程中会不断循环next()，过一个K线，执行一次next()
        if self.close_price[0] > self.sma[0]:
            # 执行买入
            # 获得默认的保证金：self.broker.comminfo[None].p.commission
            order = self.buy(
                size=500,
                price=self.data.close[0],
                exectype=backtrader.Order.Limit,
                valid=timedelta(days=1),
            )
            logger.debug("订单：买 {} ", order.ref)
            self.order_list.append(order)
        # 执行卖出条件已有持仓，且收盘价格跌破5日均线
        if self.position:
            if self.close_price[0] < self.sma[0]:
                # 执行卖出
                order = self.sell(
                    size=500,
                    price=self.data.close[0],
                    exectype=backtrader.Order.Limit,
                    valid=timedelta(days=1),
                )
                logger.debug("订单：卖 {} ", order.ref)
                self.order_list.append(order)


if __name__ == "__main__":
    # 获取数据
    # start_time = datetime(2020, 1, 1)
    # end_time = datetime(2021, 1, 1)
    # dataframe = get_k_data('600519', begin=start_time, end=end_time)
    # # =============== 为系统注入数据 =================
    # # 加载数据
    # data = backtrader.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
    store = QMTStore()
    code_list = ["600519.SH"]
    data = store.getdata(
        dataname="600519.SH",
        timeframe=bt.TimeFrame.Days,
        fromdate=datetime(2020, 1, 1),
        todate=datetime(2021, 1, 1),
        live=False,
    )
    # 初始化cerebro回测系统
    cerebral_system = (
        backtrader.Cerebro()
    )  # Cerebro引擎在后台创建了broker(经纪人)实例，系统默认每个broker的初始资金量为10000
    # 将数据传入回测系统
    cerebral_system.adddata(data)  # 导入数据，在策略中使用 self.datas 来获取数据源
    # 将交易策略加载到回测系统中
    cerebral_system.addstrategy(MyStrategy1)
    # =============== 系统设置 ==================
    # 设置启动资金为 100000
    start_cash = 1000000
    cerebral_system.broker.setcash(start_cash)
    # 设置手续费 万2.5
    cerebral_system.broker.setcommission(commission=0.00025)
    logger.debug(
        "初始资金: {} 回测期间：from {} to {}".format(start_cash, start_time, end_time)
    )
    # 运行回测系统
    cerebral_system.run()
    # 获取回测结束后的总资金
    portvalue = cerebral_system.broker.getvalue()
    pnl = portvalue - start_cash
    # 打印结果
    logger.debug("净收益: {}", pnl)
    logger.debug("总资金: {}", portvalue)
# Out:
# 2025-04-29 12:01:45.660 | DEBUG    | __main__:<module>:89 - 初始资金: 1000000 回测期间：from 2020-01-01 00:00:00 to 2021-01-01 00:00:00
# 2025-04-29 12:01:45.750 | DEBUG    | __main__:next:53 - 订单：买 6848
# 2025-04-29 12:01:45.751 | DEBUG    | __main__:notify_order:39 - 6848 已买入, 购入金额 551350.0 手续费 137.8375
# 2025-04-29 12:01:45.752 | DEBUG    | __main__:next:53 - 订单：买 6849
# 2025-04-29 12:01:45.753 | DEBUG    | __main__:notify_order:43 - 6849 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.753 | DEBUG    | __main__:next:53 - 订单：买 6850
# 2025-04-29 12:01:45.754 | DEBUG    | __main__:notify_order:43 - 6850 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.755 | DEBUG    | __main__:next:53 - 订单：买 6851
# 2025-04-29 12:01:45.756 | DEBUG    | __main__:notify_order:43 - 6851 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.756 | DEBUG    | __main__:next:53 - 订单：买 6852
# 2025-04-29 12:01:45.757 | DEBUG    | __main__:notify_order:43 - 6852 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.757 | DEBUG    | __main__:next:61 - 订单：卖 6853
# 2025-04-29 12:01:45.758 | DEBUG    | __main__:notify_order:41 - 6853 已卖出, 卖出金额 551350.0 手续费 138.75
# 2025-04-29 12:01:45.760 | DEBUG    | __main__:next:53 - 订单：买 6854
# 2025-04-29 12:01:45.762 | DEBUG    | __main__:next:53 - 订单：买 6855
# 2025-04-29 12:01:45.763 | DEBUG    | __main__:notify_order:45 - 订单 6854 超过时效，已取消
# 2025-04-29 12:01:45.764 | DEBUG    | __main__:notify_order:39 - 6855 已买入, 购入金额 535005.0 手续费 133.75125
# 2025-04-29 12:01:45.765 | DEBUG    | __main__:next:53 - 订单：买 6856
# 2025-04-29 12:01:45.766 | DEBUG    | __main__:notify_order:43 - 6856 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.767 | DEBUG    | __main__:next:53 - 订单：买 6857
# 2025-04-29 12:01:45.768 | DEBUG    | __main__:notify_order:43 - 6857 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.769 | DEBUG    | __main__:next:53 - 订单：买 6858
# 2025-04-29 12:01:45.770 | DEBUG    | __main__:notify_order:43 - 6858 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.770 | DEBUG    | __main__:next:53 - 订单：买 6859
# 2025-04-29 12:01:45.771 | DEBUG    | __main__:notify_order:43 - 6859 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.771 | DEBUG    | __main__:next:53 - 订单：买 6860
# 2025-04-29 12:01:45.772 | DEBUG    | __main__:notify_order:43 - 6860 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.773 | DEBUG    | __main__:next:61 - 订单：卖 6861
# 2025-04-29 12:01:45.774 | DEBUG    | __main__:notify_order:45 - 订单 6861 超过时效，已取消
# 2025-04-29 12:01:45.775 | DEBUG    | __main__:next:53 - 订单：买 6862
# 2025-04-29 12:01:45.776 | DEBUG    | __main__:notify_order:43 - 6862 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.777 | DEBUG    | __main__:next:61 - 订单：卖 6863
# 2025-04-29 12:01:45.778 | DEBUG    | __main__:notify_order:41 - 6863 已卖出, 卖出金额 535005.0 手续费 135.625
# 2025-04-29 12:01:45.779 | DEBUG    | __main__:next:53 - 订单：买 6864
# 2025-04-29 12:01:45.780 | DEBUG    | __main__:notify_order:39 - 6864 已买入, 购入金额 548250.0 手续费 137.0625
# 2025-04-29 12:01:45.781 | DEBUG    | __main__:next:53 - 订单：买 6865
# 2025-04-29 12:01:45.782 | DEBUG    | __main__:notify_order:43 - 6865 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.782 | DEBUG    | __main__:next:53 - 订单：买 6866
# 2025-04-29 12:01:45.783 | DEBUG    | __main__:notify_order:43 - 6866 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.784 | DEBUG    | __main__:next:61 - 订单：卖 6867
# 2025-04-29 12:01:45.784 | DEBUG    | __main__:next:61 - 订单：卖 6868
# 2025-04-29 12:01:45.786 | DEBUG    | __main__:notify_order:45 - 订单 6867 超过时效，已取消
# 2025-04-29 12:01:45.786 | DEBUG    | __main__:notify_order:41 - 6868 已卖出, 卖出金额 548250.0 手续费 134.35125000000002
# 2025-04-29 12:01:45.787 | DEBUG    | __main__:next:53 - 订单：买 6869
# 2025-04-29 12:01:45.788 | DEBUG    | __main__:notify_order:39 - 6869 已买入, 购入金额 535150.0 手续费 133.7875
# 2025-04-29 12:01:45.789 | DEBUG    | __main__:next:61 - 订单：卖 6870
# 2025-04-29 12:01:45.789 | DEBUG    | __main__:notify_order:45 - 订单 6870 超过时效，已取消
# 2025-04-29 12:01:45.790 | DEBUG    | __main__:next:53 - 订单：买 6871
# 2025-04-29 12:01:45.791 | DEBUG    | __main__:notify_order:43 - 6871 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.792 | DEBUG    | __main__:next:53 - 订单：买 6872
# 2025-04-29 12:01:45.793 | DEBUG    | __main__:notify_order:43 - 6872 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.794 | DEBUG    | __main__:next:53 - 订单：买 6873
# 2025-04-29 12:01:45.795 | DEBUG    | __main__:notify_order:43 - 6873 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.796 | DEBUG    | __main__:next:53 - 订单：买 6874
# 2025-04-29 12:01:45.797 | DEBUG    | __main__:notify_order:43 - 6874 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.798 | DEBUG    | __main__:next:53 - 订单：买 6875
# 2025-04-29 12:01:45.799 | DEBUG    | __main__:notify_order:43 - 6875 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.800 | DEBUG    | __main__:next:61 - 订单：卖 6876
# 2025-04-29 12:01:45.801 | DEBUG    | __main__:notify_order:41 - 6876 已卖出, 卖出金额 535150.0 手续费 139.25125
# 2025-04-29 12:01:45.801 | DEBUG    | __main__:next:53 - 订单：买 6877
# 2025-04-29 12:01:45.802 | DEBUG    | __main__:notify_order:39 - 6877 已买入, 购入金额 577750.0 手续费 144.4375
# 2025-04-29 12:01:45.802 | DEBUG    | __main__:next:53 - 订单：买 6878
# 2025-04-29 12:01:45.803 | DEBUG    | __main__:notify_order:43 - 6878 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.804 | DEBUG    | __main__:next:61 - 订单：卖 6879
# 2025-04-29 12:01:45.805 | DEBUG    | __main__:next:61 - 订单：卖 6880
# 2025-04-29 12:01:45.806 | DEBUG    | __main__:notify_order:45 - 订单 6879 超过时效，已取消
# 2025-04-29 12:01:45.807 | DEBUG    | __main__:notify_order:45 - 订单 6880 超过时效，已取消
# 2025-04-29 12:01:45.808 | DEBUG    | __main__:next:61 - 订单：卖 6881
# 2025-04-29 12:01:45.809 | DEBUG    | __main__:notify_order:41 - 6881 已卖出, 卖出金额 577750.0 手续费 133.375
# 2025-04-29 12:01:45.810 | DEBUG    | __main__:next:53 - 订单：买 6882
# 2025-04-29 12:01:45.811 | DEBUG    | __main__:notify_order:45 - 订单 6882 超过时效，已取消
# 2025-04-29 12:01:45.812 | DEBUG    | __main__:next:53 - 订单：买 6883
# 2025-04-29 12:01:45.813 | DEBUG    | __main__:next:53 - 订单：买 6884
# 2025-04-29 12:01:45.814 | DEBUG    | __main__:notify_order:45 - 订单 6883 超过时效，已取消
# 2025-04-29 12:01:45.815 | DEBUG    | __main__:notify_order:39 - 6884 已买入, 购入金额 536665.0 手续费 134.16625
# 2025-04-29 12:01:45.815 | DEBUG    | __main__:next:53 - 订单：买 6885
# 2025-04-29 12:01:45.816 | DEBUG    | __main__:notify_order:43 - 6885 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.816 | DEBUG    | __main__:next:53 - 订单：买 6886
# 2025-04-29 12:01:45.817 | DEBUG    | __main__:notify_order:43 - 6886 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.818 | DEBUG    | __main__:next:53 - 订单：买 6887
# 2025-04-29 12:01:45.819 | DEBUG    | __main__:notify_order:43 - 6887 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.819 | DEBUG    | __main__:next:53 - 订单：买 6888
# 2025-04-29 12:01:45.821 | DEBUG    | __main__:notify_order:43 - 6888 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.822 | DEBUG    | __main__:next:53 - 订单：买 6889
# 2025-04-29 12:01:45.824 | DEBUG    | __main__:notify_order:43 - 6889 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.824 | DEBUG    | __main__:next:53 - 订单：买 6890
# 2025-04-29 12:01:45.825 | DEBUG    | __main__:notify_order:43 - 6890 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.826 | DEBUG    | __main__:next:53 - 订单：买 6891
# 2025-04-29 12:01:45.827 | DEBUG    | __main__:notify_order:43 - 6891 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.828 | DEBUG    | __main__:next:53 - 订单：买 6892
# 2025-04-29 12:01:45.829 | DEBUG    | __main__:notify_order:43 - 6892 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.830 | DEBUG    | __main__:next:53 - 订单：买 6893
# 2025-04-29 12:01:45.831 | DEBUG    | __main__:notify_order:43 - 6893 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.832 | DEBUG    | __main__:next:53 - 订单：买 6894
# 2025-04-29 12:01:45.833 | DEBUG    | __main__:notify_order:43 - 6894 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.834 | DEBUG    | __main__:next:53 - 订单：买 6895
# 2025-04-29 12:01:45.834 | DEBUG    | __main__:notify_order:43 - 6895 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.835 | DEBUG    | __main__:next:53 - 订单：买 6896
# 2025-04-29 12:01:45.836 | DEBUG    | __main__:notify_order:43 - 6896 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.836 | DEBUG    | __main__:next:53 - 订单：买 6897
# 2025-04-29 12:01:45.837 | DEBUG    | __main__:notify_order:43 - 6897 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.838 | DEBUG    | __main__:next:53 - 订单：买 6898
# 2025-04-29 12:01:45.839 | DEBUG    | __main__:notify_order:43 - 6898 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.839 | DEBUG    | __main__:next:53 - 订单：买 6899
# 2025-04-29 12:01:45.840 | DEBUG    | __main__:notify_order:43 - 6899 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.841 | DEBUG    | __main__:next:53 - 订单：买 6900
# 2025-04-29 12:01:45.842 | DEBUG    | __main__:notify_order:43 - 6900 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.844 | DEBUG    | __main__:next:53 - 订单：买 6901
# 2025-04-29 12:01:45.845 | DEBUG    | __main__:notify_order:43 - 6901 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.846 | DEBUG    | __main__:next:61 - 订单：卖 6902
# 2025-04-29 12:01:45.847 | DEBUG    | __main__:notify_order:41 - 6902 已卖出, 卖出金额 536665.0 手续费 150.75
# 2025-04-29 12:01:45.848 | DEBUG    | __main__:next:53 - 订单：买 6903
# 2025-04-29 12:01:45.849 | DEBUG    | __main__:next:53 - 订单：买 6904
# 2025-04-29 12:01:45.850 | DEBUG    | __main__:notify_order:45 - 订单 6903 超过时效，已取消
# 2025-04-29 12:01:45.851 | DEBUG    | __main__:notify_order:39 - 6904 已买入, 购入金额 624000.0 手续费 156.0
# 2025-04-29 12:01:45.851 | DEBUG    | __main__:next:53 - 订单：买 6905
# 2025-04-29 12:01:45.852 | DEBUG    | __main__:notify_order:43 - 6905 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.853 | DEBUG    | __main__:next:53 - 订单：买 6906
# 2025-04-29 12:01:45.854 | DEBUG    | __main__:notify_order:43 - 6906 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.855 | DEBUG    | __main__:next:53 - 订单：买 6907
# 2025-04-29 12:01:45.856 | DEBUG    | __main__:notify_order:43 - 6907 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.857 | DEBUG    | __main__:next:53 - 订单：买 6908
# 2025-04-29 12:01:45.858 | DEBUG    | __main__:notify_order:43 - 6908 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.858 | DEBUG    | __main__:next:61 - 订单：卖 6909
# 2025-04-29 12:01:45.859 | DEBUG    | __main__:notify_order:45 - 订单 6909 超过时效，已取消
# 2025-04-29 12:01:45.859 | DEBUG    | __main__:next:53 - 订单：买 6910
# 2025-04-29 12:01:45.861 | DEBUG    | __main__:notify_order:43 - 6910 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.862 | DEBUG    | __main__:next:53 - 订单：买 6911
# 2025-04-29 12:01:45.863 | DEBUG    | __main__:notify_order:43 - 6911 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.864 | DEBUG    | __main__:next:53 - 订单：买 6912
# 2025-04-29 12:01:45.865 | DEBUG    | __main__:notify_order:43 - 6912 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.865 | DEBUG    | __main__:next:53 - 订单：买 6913
# 2025-04-29 12:01:45.866 | DEBUG    | __main__:notify_order:43 - 6913 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.867 | DEBUG    | __main__:next:53 - 订单：买 6914
# 2025-04-29 12:01:45.867 | DEBUG    | __main__:notify_order:43 - 6914 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.868 | DEBUG    | __main__:next:53 - 订单：买 6915
# 2025-04-29 12:01:45.869 | DEBUG    | __main__:notify_order:43 - 6915 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.869 | DEBUG    | __main__:next:61 - 订单：卖 6916
# 2025-04-29 12:01:45.872 | DEBUG    | __main__:notify_order:41 - 6916 已卖出, 卖出金额 624000.0 手续费 166.125
# 2025-04-29 12:01:45.873 | DEBUG    | __main__:next:53 - 订单：买 6917
# 2025-04-29 12:01:45.874 | DEBUG    | __main__:notify_order:39 - 6917 已买入, 购入金额 673105.0 手续费 168.27625
# 2025-04-29 12:01:45.874 | DEBUG    | __main__:next:53 - 订单：买 6918
# 2025-04-29 12:01:45.875 | DEBUG    | __main__:notify_order:43 - 6918 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.876 | DEBUG    | __main__:next:53 - 订单：买 6919
# 2025-04-29 12:01:45.877 | DEBUG    | __main__:notify_order:43 - 6919 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.878 | DEBUG    | __main__:next:53 - 订单：买 6920
# 2025-04-29 12:01:45.880 | DEBUG    | __main__:notify_order:43 - 6920 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.881 | DEBUG    | __main__:next:61 - 订单：卖 6921
# 2025-04-29 12:01:45.882 | DEBUG    | __main__:notify_order:45 - 订单 6921 超过时效，已取消
# 2025-04-29 12:01:45.883 | DEBUG    | __main__:next:53 - 订单：买 6922
# 2025-04-29 12:01:45.884 | DEBUG    | __main__:notify_order:43 - 6922 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.885 | DEBUG    | __main__:next:53 - 订单：买 6923
# 2025-04-29 12:01:45.886 | DEBUG    | __main__:notify_order:43 - 6923 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.887 | DEBUG    | __main__:next:61 - 订单：卖 6924
# 2025-04-29 12:01:45.888 | DEBUG    | __main__:notify_order:41 - 6924 已卖出, 卖出金额 673105.0 手续费 167.25
# 2025-04-29 12:01:45.889 | DEBUG    | __main__:next:53 - 订单：买 6925
# 2025-04-29 12:01:45.890 | DEBUG    | __main__:notify_order:45 - 订单 6925 超过时效，已取消
# 2025-04-29 12:01:45.891 | DEBUG    | __main__:next:53 - 订单：买 6926
# 2025-04-29 12:01:45.892 | DEBUG    | __main__:notify_order:39 - 6926 已买入, 购入金额 708005.0 手续费 177.00125
# 2025-04-29 12:01:45.893 | DEBUG    | __main__:next:53 - 订单：买 6927
# 2025-04-29 12:01:45.894 | DEBUG    | __main__:notify_order:43 - 6927 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.895 | DEBUG    | __main__:next:53 - 订单：买 6928
# 2025-04-29 12:01:45.896 | DEBUG    | __main__:notify_order:43 - 6928 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.897 | DEBUG    | __main__:next:53 - 订单：买 6929
# 2025-04-29 12:01:45.899 | DEBUG    | __main__:notify_order:43 - 6929 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.900 | DEBUG    | __main__:next:53 - 订单：买 6930
# 2025-04-29 12:01:45.901 | DEBUG    | __main__:notify_order:43 - 6930 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.902 | DEBUG    | __main__:next:61 - 订单：卖 6931
# 2025-04-29 12:01:45.904 | DEBUG    | __main__:notify_order:41 - 6931 已卖出, 卖出金额 708005.0 手续费 176.0
# 2025-04-29 12:01:45.905 | DEBUG    | __main__:next:53 - 订单：买 6932
# 2025-04-29 12:01:45.906 | DEBUG    | __main__:next:53 - 订单：买 6933
# 2025-04-29 12:01:45.907 | DEBUG    | __main__:notify_order:45 - 订单 6932 超过时效，已取消
# 2025-04-29 12:01:45.908 | DEBUG    | __main__:notify_order:39 - 6933 已买入, 购入金额 705505.0 手续费 176.37625
# 2025-04-29 12:01:45.909 | DEBUG    | __main__:next:61 - 订单：卖 6934
# 2025-04-29 12:01:45.911 | DEBUG    | __main__:notify_order:41 - 6934 已卖出, 卖出金额 705505.0 手续费 175.0575
# 2025-04-29 12:01:45.912 | DEBUG    | __main__:next:53 - 订单：买 6935
# 2025-04-29 12:01:45.913 | DEBUG    | __main__:notify_order:45 - 订单 6935 超过时效，已取消
# 2025-04-29 12:01:45.915 | DEBUG    | __main__:next:53 - 订单：买 6936
# 2025-04-29 12:01:45.916 | DEBUG    | __main__:notify_order:39 - 6936 已买入, 购入金额 702450.0 手续费 175.6125
# 2025-04-29 12:01:45.917 | DEBUG    | __main__:next:53 - 订单：买 6937
# 2025-04-29 12:01:45.919 | DEBUG    | __main__:notify_order:43 - 6937 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.919 | DEBUG    | __main__:next:53 - 订单：买 6938
# 600519.SH历史数据装载成功！
# 2025-04-29 12:01:45.920 | DEBUG    | __main__:notify_order:43 - 6938 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.921 | DEBUG    | __main__:next:53 - 订单：买 6939
# 2025-04-29 12:01:45.922 | DEBUG    | __main__:notify_order:43 - 6939 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.923 | DEBUG    | __main__:next:53 - 订单：买 6940
# 2025-04-29 12:01:45.924 | DEBUG    | __main__:notify_order:43 - 6940 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.925 | DEBUG    | __main__:next:53 - 订单：买 6941
# 2025-04-29 12:01:45.927 | DEBUG    | __main__:notify_order:43 - 6941 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.928 | DEBUG    | __main__:next:53 - 订单：买 6942
# 2025-04-29 12:01:45.929 | DEBUG    | __main__:notify_order:43 - 6942 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.930 | DEBUG    | __main__:next:53 - 订单：买 6943
# 2025-04-29 12:01:45.931 | DEBUG    | __main__:notify_order:43 - 6943 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.932 | DEBUG    | __main__:next:53 - 订单：买 6944
# 2025-04-29 12:01:45.933 | DEBUG    | __main__:notify_order:43 - 6944 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.936 | DEBUG    | __main__:next:53 - 订单：买 6945
# 2025-04-29 12:01:45.936 | DEBUG    | __main__:notify_order:43 - 6945 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.938 | DEBUG    | __main__:next:53 - 订单：买 6946
# 2025-04-29 12:01:45.938 | DEBUG    | __main__:notify_order:43 - 6946 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.939 | DEBUG    | __main__:next:53 - 订单：买 6947
# 2025-04-29 12:01:45.940 | DEBUG    | __main__:notify_order:43 - 6947 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.940 | DEBUG    | __main__:next:53 - 订单：买 6948
# 2025-04-29 12:01:45.941 | DEBUG    | __main__:notify_order:43 - 6948 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.942 | DEBUG    | __main__:next:53 - 订单：买 6949
# 2025-04-29 12:01:45.943 | DEBUG    | __main__:notify_order:43 - 6949 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.945 | DEBUG    | __main__:next:53 - 订单：买 6950
# 2025-04-29 12:01:45.946 | DEBUG    | __main__:notify_order:43 - 6950 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.947 | DEBUG    | __main__:next:53 - 订单：买 6951
# 2025-04-29 12:01:45.948 | DEBUG    | __main__:notify_order:43 - 6951 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.949 | DEBUG    | __main__:next:53 - 订单：买 6952
# 2025-04-29 12:01:45.950 | DEBUG    | __main__:notify_order:43 - 6952 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.951 | DEBUG    | __main__:next:53 - 订单：买 6953
# 2025-04-29 12:01:45.952 | DEBUG    | __main__:notify_order:43 - 6953 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.953 | DEBUG    | __main__:next:53 - 订单：买 6954
# 2025-04-29 12:01:45.953 | DEBUG    | __main__:notify_order:43 - 6954 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.954 | DEBUG    | __main__:next:61 - 订单：卖 6955
# 2025-04-29 12:01:45.956 | DEBUG    | __main__:notify_order:41 - 6955 已卖出, 卖出金额 702450.0 手续费 202.5
# 2025-04-29 12:01:45.957 | DEBUG    | __main__:next:53 - 订单：买 6956
# 2025-04-29 12:01:45.958 | DEBUG    | __main__:notify_order:39 - 6956 已买入, 购入金额 829000.0 手续费 207.25
# 2025-04-29 12:01:45.959 | DEBUG    | __main__:next:53 - 订单：买 6957
# 2025-04-29 12:01:45.960 | DEBUG    | __main__:notify_order:43 - 6957 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.962 | DEBUG    | __main__:next:53 - 订单：买 6958
# 2025-04-29 12:01:45.963 | DEBUG    | __main__:notify_order:43 - 6958 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.966 | DEBUG    | __main__:next:61 - 订单：卖 6959
# 2025-04-29 12:01:45.967 | DEBUG    | __main__:notify_order:45 - 订单 6959 超过时效，已取消
# 2025-04-29 12:01:45.968 | DEBUG    | __main__:next:61 - 订单：卖 6960
# 2025-04-29 12:01:45.969 | DEBUG    | __main__:notify_order:41 - 6960 已卖出, 卖出金额 829000.0 手续费 203.75
# 2025-04-29 12:01:45.970 | DEBUG    | __main__:next:53 - 订单：买 6961
# 2025-04-29 12:01:45.971 | DEBUG    | __main__:notify_order:39 - 6961 已买入, 购入金额 835000.0 手续费 208.75
# 2025-04-29 12:01:45.973 | DEBUG    | __main__:next:53 - 订单：买 6962
# 2025-04-29 12:01:45.974 | DEBUG    | __main__:notify_order:43 - 6962 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.975 | DEBUG    | __main__:next:53 - 订单：买 6963
# 2025-04-29 12:01:45.975 | DEBUG    | __main__:notify_order:43 - 6963 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.977 | DEBUG    | __main__:next:53 - 订单：买 6964
# 2025-04-29 12:01:45.978 | DEBUG    | __main__:notify_order:43 - 6964 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.979 | DEBUG    | __main__:next:61 - 订单：卖 6965
# 2025-04-29 12:01:45.980 | DEBUG    | __main__:notify_order:41 - 6965 已卖出, 卖出金额 835000.0 手续费 209.375
# 2025-04-29 12:01:45.982 | DEBUG    | __main__:next:53 - 订单：买 6966
# 2025-04-29 12:01:45.984 | DEBUG    | __main__:notify_order:39 - 6966 已买入, 购入金额 817500.0 手续费 204.375
# 2025-04-29 12:01:45.985 | DEBUG    | __main__:next:53 - 订单：买 6967
# 2025-04-29 12:01:45.986 | DEBUG    | __main__:notify_order:43 - 6967 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.987 | DEBUG    | __main__:next:53 - 订单：买 6968
# 2025-04-29 12:01:45.988 | DEBUG    | __main__:notify_order:43 - 6968 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.988 | DEBUG    | __main__:next:53 - 订单：买 6969
# 2025-04-29 12:01:45.989 | DEBUG    | __main__:notify_order:43 - 6969 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.990 | DEBUG    | __main__:next:53 - 订单：买 6970
# 2025-04-29 12:01:45.991 | DEBUG    | __main__:notify_order:43 - 6970 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:45.992 | DEBUG    | __main__:next:61 - 订单：卖 6971
# 2025-04-29 12:01:45.993 | DEBUG    | __main__:notify_order:41 - 6971 已卖出, 卖出金额 817500.0 手续费 209.125
# 2025-04-29 12:01:45.995 | DEBUG    | __main__:next:53 - 订单：买 6972
# 2025-04-29 12:01:45.997 | DEBUG    | __main__:next:53 - 订单：买 6973
# 2025-04-29 12:01:45.998 | DEBUG    | __main__:notify_order:45 - 订单 6972 超过时效，已取消
# 2025-04-29 12:01:45.999 | DEBUG    | __main__:notify_order:39 - 6973 已买入, 购入金额 863500.0 手续费 215.875
# 2025-04-29 12:01:45.999 | DEBUG    | __main__:next:53 - 订单：买 6974
# 2025-04-29 12:01:46.000 | DEBUG    | __main__:notify_order:43 - 6974 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.001 | DEBUG    | __main__:next:53 - 订单：买 6975
# 2025-04-29 12:01:46.002 | DEBUG    | __main__:notify_order:43 - 6975 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.003 | DEBUG    | __main__:next:53 - 订单：买 6976
# 2025-04-29 12:01:46.004 | DEBUG    | __main__:notify_order:43 - 6976 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.005 | DEBUG    | __main__:next:53 - 订单：买 6977
# 2025-04-29 12:01:46.006 | DEBUG    | __main__:notify_order:43 - 6977 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.007 | DEBUG    | __main__:next:53 - 订单：买 6978
# 2025-04-29 12:01:46.008 | DEBUG    | __main__:notify_order:43 - 6978 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.009 | DEBUG    | __main__:next:53 - 订单：买 6979
# 2025-04-29 12:01:46.010 | DEBUG    | __main__:notify_order:43 - 6979 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.011 | DEBUG    | __main__:next:53 - 订单：买 6980
# 2025-04-29 12:01:46.013 | DEBUG    | __main__:notify_order:43 - 6980 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.015 | DEBUG    | __main__:next:61 - 订单：卖 6981
# 2025-04-29 12:01:46.017 | DEBUG    | __main__:notify_order:45 - 订单 6981 超过时效，已取消
# 2025-04-29 12:01:46.017 | DEBUG    | __main__:next:61 - 订单：卖 6982
# 2025-04-29 12:01:46.018 | DEBUG    | __main__:notify_order:41 - 6982 已卖出, 卖出金额 863500.0 手续费 216.5
# 2025-04-29 12:01:46.020 | DEBUG    | __main__:next:53 - 订单：买 6983
# 2025-04-29 12:01:46.021 | DEBUG    | __main__:notify_order:45 - 订单 6983 超过时效，已取消
# 2025-04-29 12:01:46.022 | DEBUG    | __main__:next:53 - 订单：买 6984
# 2025-04-29 12:01:46.022 | DEBUG    | __main__:notify_order:39 - 6984 已买入, 购入金额 883000.0 手续费 220.75
# 2025-04-29 12:01:46.023 | DEBUG    | __main__:next:53 - 订单：买 6985
# 2025-04-29 12:01:46.024 | DEBUG    | __main__:notify_order:43 - 6985 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.025 | DEBUG    | __main__:next:61 - 订单：卖 6986
# 2025-04-29 12:01:46.025 | DEBUG    | __main__:next:61 - 订单：卖 6987
# 2025-04-29 12:01:46.028 | DEBUG    | __main__:notify_order:45 - 订单 6986 超过时效，已取消
# 2025-04-29 12:01:46.029 | DEBUG    | __main__:notify_order:41 - 6987 已卖出, 卖出金额 883000.0 手续费 208.815
# 2025-04-29 12:01:46.031 | DEBUG    | __main__:next:53 - 订单：买 6988
# 2025-04-29 12:01:46.032 | DEBUG    | __main__:notify_order:39 - 6988 已买入, 购入金额 830500.0 手续费 207.625
# 2025-04-29 12:01:46.033 | DEBUG    | __main__:next:53 - 订单：买 6989
# 2025-04-29 12:01:46.034 | DEBUG    | __main__:notify_order:43 - 6989 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.034 | DEBUG    | __main__:next:53 - 订单：买 6990
# 2025-04-29 12:01:46.035 | DEBUG    | __main__:notify_order:43 - 6990 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.036 | DEBUG    | __main__:next:53 - 订单：买 6991
# 2025-04-29 12:01:46.037 | DEBUG    | __main__:notify_order:43 - 6991 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.037 | DEBUG    | __main__:next:53 - 订单：买 6992
# 2025-04-29 12:01:46.038 | DEBUG    | __main__:notify_order:43 - 6992 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.039 | DEBUG    | __main__:next:53 - 订单：买 6993
# 2025-04-29 12:01:46.040 | DEBUG    | __main__:notify_order:43 - 6993 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.041 | DEBUG    | __main__:next:53 - 订单：买 6994
# 2025-04-29 12:01:46.042 | DEBUG    | __main__:notify_order:43 - 6994 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.043 | DEBUG    | __main__:next:61 - 订单：卖 6995
# 2025-04-29 12:01:46.044 | DEBUG    | __main__:notify_order:41 - 6995 已卖出, 卖出金额 830500.0 手续费 215.625
# 2025-04-29 12:01:46.046 | DEBUG    | __main__:next:53 - 订单：买 6996
# 2025-04-29 12:01:46.047 | DEBUG    | __main__:notify_order:39 - 6996 已买入, 购入金额 867000.0 手续费 216.75
# 2025-04-29 12:01:46.048 | DEBUG    | __main__:next:53 - 订单：买 6997
# 2025-04-29 12:01:46.049 | DEBUG    | __main__:notify_order:43 - 6997 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.050 | DEBUG    | __main__:next:53 - 订单：买 6998
# 2025-04-29 12:01:46.050 | DEBUG    | __main__:notify_order:43 - 6998 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.051 | DEBUG    | __main__:next:61 - 订单：卖 6999
# 2025-04-29 12:01:46.052 | DEBUG    | __main__:notify_order:45 - 订单 6999 超过时效，已取消
# 2025-04-29 12:01:46.053 | DEBUG    | __main__:next:61 - 订单：卖 7000
# 2025-04-29 12:01:46.054 | DEBUG    | __main__:notify_order:41 - 7000 已卖出, 卖出金额 867000.0 手续费 205.37500000000003
# 2025-04-29 12:01:46.055 | DEBUG    | __main__:next:53 - 订单：买 7001
# 2025-04-29 12:01:46.056 | DEBUG    | __main__:notify_order:39 - 7001 已买入, 购入金额 838000.0 手续费 209.5
# 2025-04-29 12:01:46.057 | DEBUG    | __main__:next:53 - 订单：买 7002
# 2025-04-29 12:01:46.058 | DEBUG    | __main__:notify_order:43 - 7002 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.059 | DEBUG    | __main__:next:53 - 订单：买 7003
# 2025-04-29 12:01:46.060 | DEBUG    | __main__:notify_order:43 - 7003 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.062 | DEBUG    | __main__:next:53 - 订单：买 7004
# 2025-04-29 12:01:46.063 | DEBUG    | __main__:notify_order:43 - 7004 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.064 | DEBUG    | __main__:next:53 - 订单：买 7005
# 2025-04-29 12:01:46.065 | DEBUG    | __main__:notify_order:43 - 7005 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.066 | DEBUG    | __main__:next:53 - 订单：买 7006
# 2025-04-29 12:01:46.066 | DEBUG    | __main__:notify_order:43 - 7006 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.067 | DEBUG    | __main__:next:53 - 订单：买 7007
# 2025-04-29 12:01:46.068 | DEBUG    | __main__:notify_order:43 - 7007 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.069 | DEBUG    | __main__:next:53 - 订单：买 7008
# 2025-04-29 12:01:46.070 | DEBUG    | __main__:notify_order:43 - 7008 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.071 | DEBUG    | __main__:next:53 - 订单：买 7009
# 2025-04-29 12:01:46.072 | DEBUG    | __main__:notify_order:43 - 7009 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.073 | DEBUG    | __main__:next:53 - 订单：买 7010
# 2025-04-29 12:01:46.074 | DEBUG    | __main__:notify_order:43 - 7010 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.075 | DEBUG    | __main__:next:53 - 订单：买 7011
# 2025-04-29 12:01:46.076 | DEBUG    | __main__:notify_order:43 - 7011 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.077 | DEBUG    | __main__:next:61 - 订单：卖 7012
# 2025-04-29 12:01:46.079 | DEBUG    | __main__:notify_order:45 - 订单 7012 超过时效，已取消
# 2025-04-29 12:01:46.080 | DEBUG    | __main__:next:53 - 订单：买 7013
# 2025-04-29 12:01:46.081 | DEBUG    | __main__:notify_order:43 - 7013 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.082 | DEBUG    | __main__:next:61 - 订单：卖 7014
# 2025-04-29 12:01:46.083 | DEBUG    | __main__:notify_order:41 - 7014 已卖出, 卖出金额 838000.0 手续费 214.475
# 2025-04-29 12:01:46.085 | DEBUG    | __main__:next:53 - 订单：买 7015
# 2025-04-29 12:01:46.086 | DEBUG    | __main__:notify_order:39 - 7015 已买入, 购入金额 860000.0 手续费 215.0
# 2025-04-29 12:01:46.087 | DEBUG    | __main__:next:53 - 订单：买 7016
# 2025-04-29 12:01:46.087 | DEBUG    | __main__:notify_order:43 - 7016 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.088 | DEBUG    | __main__:next:53 - 订单：买 7017
# 2025-04-29 12:01:46.089 | DEBUG    | __main__:notify_order:43 - 7017 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.090 | DEBUG    | __main__:next:53 - 订单：买 7018
# 2025-04-29 12:01:46.091 | DEBUG    | __main__:notify_order:43 - 7018 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.092 | DEBUG    | __main__:next:61 - 订单：卖 7019
# 2025-04-29 12:01:46.093 | DEBUG    | __main__:notify_order:41 - 7019 已卖出, 卖出金额 860000.0 手续费 215.86
# 2025-04-29 12:01:46.095 | DEBUG    | __main__:next:53 - 订单：买 7020
# 2025-04-29 12:01:46.096 | DEBUG    | __main__:notify_order:39 - 7020 已买入, 购入金额 868500.0 手续费 217.125
# 2025-04-29 12:01:46.098 | DEBUG    | __main__:next:53 - 订单：买 7021
# 2025-04-29 12:01:46.099 | DEBUG    | __main__:notify_order:43 - 7021 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.100 | DEBUG    | __main__:next:53 - 订单：买 7022
# 2025-04-29 12:01:46.101 | DEBUG    | __main__:notify_order:43 - 7022 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.102 | DEBUG    | __main__:next:53 - 订单：买 7023
# 2025-04-29 12:01:46.102 | DEBUG    | __main__:notify_order:43 - 7023 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.104 | DEBUG    | __main__:next:53 - 订单：买 7024
# 2025-04-29 12:01:46.105 | DEBUG    | __main__:notify_order:43 - 7024 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.107 | DEBUG    | __main__:next:53 - 订单：买 7025
# 2025-04-29 12:01:46.108 | DEBUG    | __main__:notify_order:43 - 7025 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.109 | DEBUG    | __main__:next:53 - 订单：买 7026
# 2025-04-29 12:01:46.110 | DEBUG    | __main__:notify_order:43 - 7026 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.111 | DEBUG    | __main__:next:53 - 订单：买 7027
# 2025-04-29 12:01:46.113 | DEBUG    | __main__:notify_order:43 - 7027 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.114 | DEBUG    | __main__:next:61 - 订单：卖 7028
# 2025-04-29 12:01:46.115 | DEBUG    | __main__:notify_order:45 - 订单 7028 超过时效，已取消
# 2025-04-29 12:01:46.116 | DEBUG    | __main__:next:61 - 订单：卖 7029
# 2025-04-29 12:01:46.117 | DEBUG    | __main__:notify_order:41 - 7029 已卖出, 卖出金额 868500.0 手续费 229.1875
# 2025-04-29 12:01:46.119 | DEBUG    | __main__:next:53 - 订单：买 7030
# 2025-04-29 12:01:46.120 | DEBUG    | __main__:notify_order:39 - 7030 已买入, 购入金额 920000.0 手续费 230.0
# 2025-04-29 12:01:46.121 | DEBUG    | __main__:next:53 - 订单：买 7031
# 2025-04-29 12:01:46.122 | DEBUG    | __main__:notify_order:43 - 7031 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.123 | DEBUG    | __main__:next:53 - 订单：买 7032
# 2025-04-29 12:01:46.124 | DEBUG    | __main__:notify_order:43 - 7032 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.124 | DEBUG    | __main__:next:53 - 订单：买 7033
# 2025-04-29 12:01:46.125 | DEBUG    | __main__:notify_order:43 - 7033 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.129 | DEBUG    | __main__:next:53 - 订单：买 7034
# 2025-04-29 12:01:46.130 | DEBUG    | __main__:notify_order:43 - 7034 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.132 | DEBUG    | __main__:next:61 - 订单：卖 7035
# 2025-04-29 12:01:46.133 | DEBUG    | __main__:notify_order:41 - 7035 已卖出, 卖出金额 920000.0 手续费 230.20625
# 2025-04-29 12:01:46.135 | DEBUG    | __main__:next:53 - 订单：买 7036
# 2025-04-29 12:01:46.136 | DEBUG    | __main__:notify_order:39 - 7036 已买入, 购入金额 936500.0 手续费 234.125
# 2025-04-29 12:01:46.137 | DEBUG    | __main__:next:53 - 订单：买 7037
# 2025-04-29 12:01:46.139 | DEBUG    | __main__:notify_order:43 - 7037 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.139 | DEBUG    | __main__:next:53 - 订单：买 7038
# 2025-04-29 12:01:46.141 | DEBUG    | __main__:notify_order:43 - 7038 订单取消、保证金不足、金额不足拒绝交易
# 2025-04-29 12:01:46.142 | DEBUG    | __main__:next:53 - 订单：买 7039
# 2025-04-29 12:01:46.143 | DEBUG    | __main__:<module>:96 - 净收益: 254241.23750000028
# 2025-04-29 12:01:46.144 | DEBUG    | __main__:<module>:97 - 总资金: 1254241.2375000003

# %% [markdown]
# ### Train和Test流程demo

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import efinance
import optuna


def get_k_data(stock_code, begin: datetime, end: datetime) -> pd.DataFrame:
    """根据efinance工具包获取股票数据
    :param stock_code:股票代码
    :param begin: 开始日期
    :param end: 结束日期
    """
    # stock_code = '600519'  # 股票代码，茅台
    k_dataframe: pd.DataFrame = efinance.stock.get_quote_history(
        stock_code, beg=begin.strftime("%Y%m%d"), end=end.strftime("%Y%m%d")
    )
    k_dataframe = k_dataframe.iloc[:, :9]
    k_dataframe.columns = [
        "name",
        "code",
        "date",
        "open",
        "close",
        "high",
        "low",
        "volume",
        "turnover",
    ]
    k_dataframe.index = pd.to_datetime(k_dataframe.date)
    k_dataframe.drop(["name", "code", "date"], axis=1, inplace=True)
    return k_dataframe


class SmaCross(bt.SignalStrategy):
    params = (
        ("period1", 10),
        ("period2", 30),
    )

    def __init__(self):
        sma1, sma2 = bt.ind.SMA(period=self.p.period1), bt.ind.SMA(
            period=self.p.period2
        )
        crossover = bt.ind.CrossOver(sma1, sma2)
        self.signal_add(bt.SIGNAL_LONG, crossover)


class backtest:
    def __init__(self, data_list, strategy):
        self.data_list = data_list
        self.strategy = strategy
        self.cerebro = bt.Cerebro()
        if isinstance(data_list, list):
            for data in data_list:
                self.cerebro.adddata(data)
        else:
            self.cerebro.adddata(data_list)
        self.start_cash = 1000000
        self.cerebro.broker.setcash(self.start_cash)
        self.cerebro.broker.setcommission(commission=0.00025)

    def __call__(self, trial):
        p1 = trial.suggest_int("period1", 1, 50)
        p2 = trial.suggest_int("period2", 1, 50)
        self.cerebro.strats = []
        self.cerebro.addstrategy(self.strategy, period1=int(p1), period2=int(p2))
        self.cerebro.run()
        return self.start_cash - self.cerebro.broker.getvalue()


def train(data_list, strategy):
    study = optuna.create_study(direction="maximize")
    study.optimize(
        backtest(data_list=data_list, strategy=strategy), n_trials=10, n_jobs=1
    )
    trial = study.best_trial

    return study.best_trial.value, study.best_trial.params


def test(data_list, strategy, *args, **kwargs):
    data_list = data_list
    strategy = strategy
    cerebro = bt.Cerebro()
    if isinstance(data_list, list):
        for data in data_list:
            cerebro.adddata(data)
    else:
        cerebro.adddata(data_list)
    start_cash = 1000000
    cerebro.broker.setcash(start_cash)
    cerebro.broker.setcommission(commission=0.00025)

    cerebro.addstrategy(strategy, *args, **kwargs)
    cerebro.run()
    return start_cash - cerebro.broker.getvalue()


#### Train
# start_time = datetime(2020, 1, 1)
# end_time = datetime(2021, 1, 1)
# dataframe = get_k_data('600519', begin=start_time, end=end_time)
# data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
store = QMTStore()
code_list = ["600519.SH"]
data = store.getdata(
    dataname="600519.SH",
    timeframe=bt.TimeFrame.Days,
    fromdate=datetime(2020, 1, 1),
    todate=datetime(2021, 1, 1),
    live=False,
)
value, params = train(data, SmaCross)
print("train value: ", value)


#### Test
# start_time = datetime(2021, 1, 1)
# end_time = datetime(2022, 1, 1)
# dataframe = get_k_data('600519', begin=start_time, end=end_time)
# data = bt.feeds.PandasData(dataname=dataframe, fromdate=start_time, todate=end_time)
store = QMTStore()
code_list = ["600519.SH"]
data = store.getdata(
    dataname="600519.SH",
    timeframe=bt.TimeFrame.Days,
    fromdate=datetime(2020, 1, 1),
    todate=datetime(2021, 1, 1),
    live=False,
)
print("test value: ", test(data, SmaCross, **params))
# Out:
# [I 2025-04-29 12:05:16,157] A new study created in memory with name: no-name-65cab7b5-4423-4b28-9e09-33fe4e2bc392
# [I 2025-04-29 12:05:16,281] Trial 0 finished with value: -774.4969474999234 and parameters: {'period1': 14, 'period2': 47}. Best is trial 0 with value: -774.4969474999234.
# [I 2025-04-29 12:05:16,378] Trial 1 finished with value: -743.6604049999733 and parameters: {'period1': 4, 'period2': 41}. Best is trial 1 with value: -743.6604049999733.
# 600519.SH历史数据装载成功！
# 600519.SH历史数据装载成功！
# 600519.SH历史数据装载成功！
# [I 2025-04-29 12:05:16,476] Trial 2 finished with value: -223.87076250032987 and parameters: {'period1': 28, 'period2': 25}. Best is trial 2 with value: -223.87076250032987.
# [I 2025-04-29 12:05:16,595] Trial 3 finished with value: 91.35541499999817 and parameters: {'period1': 42, 'period2': 36}. Best is trial 3 with value: 91.35541499999817.
# [I 2025-04-29 12:05:16,702] Trial 4 finished with value: -631.1280349999433 and parameters: {'period1': 18, 'period2': 28}. Best is trial 3 with value: 91.35541499999817.
# 600519.SH历史数据装载成功！
# 600519.SH历史数据装载成功！
# [I 2025-04-29 12:05:16,812] Trial 5 finished with value: -543.9177599998657 and parameters: {'period1': 1, 'period2': 35}. Best is trial 3 with value: 91.35541499999817.
# [I 2025-04-29 12:05:16,919] Trial 6 finished with value: -234.8400849996833 and parameters: {'period1': 29, 'period2': 28}. Best is trial 3 with value: 91.35541499999817.
# 600519.SH历史数据装载成功！
# 600519.SH历史数据装载成功！
# [I 2025-04-29 12:05:17,022] Trial 7 finished with value: -660.1155199999921 and parameters: {'period1': 5, 'period2': 50}. Best is trial 3 with value: 91.35541499999817.
# [I 2025-04-29 12:05:17,127] Trial 8 finished with value: -655.0870325000724 and parameters: {'period1': 18, 'period2': 27}. Best is trial 3 with value: 91.35541499999817.
# 600519.SH历史数据装载成功！
# 600519.SH历史数据装载成功！
# [I 2025-04-29 12:05:17,230] Trial 9 finished with value: -446.77689749968704 and parameters: {'period1': 6, 'period2': 16}. Best is trial 3 with value: 91.35541499999817.
# 600519.SH历史数据装载成功！
# train value:  91.35541499999817
# 600519.SH历史数据装载成功！
# test value:  91.35541499999817
